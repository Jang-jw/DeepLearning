# %% [markdown]
# #### OpenCV : 이미지 처리 라이브러리
#     - ComputerVision(컴퓨터 비전)분야는 사람이 시각 정보를 입력값으로 하여 행동하기 이전에 판단하고 생각하는 부분을 컴퓨터가 대신하도록 돕는 학문입니다. 쉽게 말해서, 시각적인 입력 데이터(영상)를 주로 다루는 인공지능 학문이다.
#     - 컴퓨터 비전을 쉽게 도와주는 도구 > OpenCV (영상처리, 3D구성, 추적, 인식, 탐지)

# %%
# 설치 !pip install opencv-python 
import cv2
cv2.__version__
# Out:
# '4.8.0'

# %%
# 이미지 잘라내기, 색상 변형, 중요한 표시, 이미지 경계선 추출 ... 
# 카메라 화면 캡쳐 
# 이미지 저장

# %%
# !pip install ultralytics --user
# Out:
# Requirement already satisfied: ultralytics in c:\users\user\appdata\roaming\python\python39\site-packages (8.0.199)
# Requirement already satisfied: requests>=2.23.0 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (2.28.1)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (3.5.2)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (0.11.2)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (1.9.1)
# Requirement already satisfied: py-cpuinfo in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: psutil in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (1.4.4)
# Requirement already satisfied: numpy>=1.22.2 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (1.24.4)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (6.0)
# Requirement already satisfied: torch>=1.8.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from ultralytics) (2.1.0)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (4.64.1)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (9.2.0)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\user\anaconda3\lib\site-packages (from ultralytics) (4.8.0.74)
# Requirement already satisfied: thop>=0.1.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from ultralytics) (0.16.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2022.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (1.26.11)
# Requirement already satisfied: sympy in c:\users\user\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (1.10.1)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: networkx in c:\users\user\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2.8.4)
# Requirement already satisfied: fsspec in c:\users\user\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2022.7.1)
# Requirement already satisfied: typing-extensions in c:\users\user\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.3.0)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2.11.3)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.5)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\user\anaconda3\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.2.1)

# %%
import cv2
from ultralytics import YOLO

# Load the YOLOv8 model
# best.pt 로 변경 (colab 에서 학습하고 저장한 모델)
model = YOLO('./best.pt')

# Open the video file
video_path = "./pexels-danik-prihodko-7427847 (360p).mp4"
cap = cv2.VideoCapture(video_path) # 재생 파일 
# cap = cv2.VideoCapture(0) # 카메라 연결 0 
# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 detection", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            # waitKey 아스키 값으로 받아들임 
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()

cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 Paper, 2 Scissorss, 57.6ms
# Speed: 3.0ms preprocess, 57.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Scissorss, 57.8ms
# Speed: 2.0ms preprocess, 57.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 51.9ms
# Speed: 1.0ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Scissorss, 50.4ms
# Speed: 1.0ms preprocess, 50.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Rock, 2 Scissorss, 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Papers, 1 Scissors, 50.1ms
# Speed: 1.0ms preprocess, 50.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Scissors, 53.0ms
# Speed: 1.0ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Scissorss, 53.7ms
# Speed: 1.0ms preprocess, 53.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Scissors, 52.0ms
# Speed: 1.0ms preprocess, 52.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Scissors, 50.1ms
# Speed: 1.0ms preprocess, 50.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Scissors, 51.1ms
# Speed: 1.0ms preprocess, 51.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Papers, 2 Scissorss, 54.7ms
# Speed: 1.0ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Scissorss, 53.1ms
# Speed: 2.0ms preprocess, 53.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Scissorss, 53.1ms
# Speed: 1.0ms preprocess, 53.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Scissorss, 53.3ms
# Speed: 1.0ms preprocess, 53.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Scissorss, 58.8ms
# Speed: 2.0ms preprocess, 58.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Scissorss, 53.1ms
# Speed: 1.0ms preprocess, 53.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Scissorss, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Scissorss, 52.9ms
# Speed: 1.0ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Scissorss, 53.2ms
# Speed: 2.0ms preprocess, 53.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Scissorss, 52.9ms
# Speed: 1.0ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Scissorss, 52.4ms
# Speed: 1.0ms preprocess, 52.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Scissorss, 50.7ms
# Speed: 2.0ms preprocess, 50.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Scissorss, 54.1ms
# Speed: 2.0ms preprocess, 54.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Scissorss, 53.1ms
# Speed: 1.0ms preprocess, 53.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 3 Scissorss, 53.9ms
# Speed: 1.0ms preprocess, 53.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Scissorss, 54.0ms
# Speed: 1.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 3 Scissorss, 52.8ms
# Speed: 1.0ms preprocess, 52.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 4 Scissorss, 53.0ms
# Speed: 1.0ms preprocess, 53.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 4 Scissorss, 51.1ms
# Speed: 1.0ms preprocess, 51.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 4 Scissorss, 52.7ms
# Speed: 2.0ms preprocess, 52.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Scissorss, 51.9ms
# Speed: 1.0ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Scissorss, 51.9ms
# Speed: 1.0ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Scissorss, 52.4ms
# Speed: 1.0ms preprocess, 52.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Scissorss, 54.1ms
# Speed: 1.0ms preprocess, 54.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Scissorss, 54.9ms
# Speed: 1.0ms preprocess, 54.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Scissorss, 52.9ms
# Speed: 1.0ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Scissorss, 50.9ms
# Speed: 1.0ms preprocess, 50.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Scissorss, 50.9ms
# Speed: 1.0ms preprocess, 50.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 50.9ms
# Speed: 1.0ms preprocess, 50.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Scissors, 50.8ms
# Speed: 1.0ms preprocess, 50.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Scissors, 50.4ms
# Speed: 1.0ms preprocess, 50.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Scissors, 50.9ms
# Speed: 2.0ms preprocess, 50.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Scissorss, 52.2ms
# Speed: 2.0ms preprocess, 52.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 51.7ms
# Speed: 1.0ms preprocess, 51.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Scissorss, 50.9ms
# Speed: 0.9ms preprocess, 50.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 52.0ms
# Speed: 1.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 52.5ms
# Speed: 2.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Scissorss, 52.1ms
# Speed: 1.0ms preprocess, 52.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Scissorss, 52.0ms
# Speed: 1.4ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Scissorss, 50.5ms
# Speed: 2.0ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Scissorss, 52.9ms
# Speed: 2.0ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 51.9ms
# Speed: 1.0ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Scissorss, 51.9ms
# Speed: 0.9ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Scissorss, 51.9ms
# Speed: 1.0ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Scissorss, 52.9ms
# Speed: 1.0ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 51.9ms
# Speed: 1.0ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 51.9ms
# Speed: 1.0ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 49.8ms
# Speed: 2.0ms preprocess, 49.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Rock, 1 Scissors, 52.9ms
# Speed: 1.0ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Rock, 1 Scissors, 50.9ms
# Speed: 1.0ms preprocess, 50.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Scissors, 51.9ms
# Speed: 1.0ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 51.2ms
# Speed: 2.0ms preprocess, 51.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Scissors, 51.8ms
# Speed: 1.0ms preprocess, 51.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Scissors, 61.8ms
# Speed: 1.0ms preprocess, 61.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Rock, 1 Scissors, 51.8ms
# Speed: 1.0ms preprocess, 51.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Rock, 1 Scissors, 53.9ms
# Speed: 2.0ms preprocess, 53.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Rock, 51.2ms
# Speed: 1.0ms preprocess, 51.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Rock, 50.9ms
# Speed: 1.0ms preprocess, 50.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Rock, 51.2ms
# Speed: 1.0ms preprocess, 51.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Rock, 1 Scissors, 50.9ms
# Speed: 1.0ms preprocess, 50.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Rock, 1 Scissors, 49.0ms
# Speed: 1.1ms preprocess, 49.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Rock, 1 Scissors, 51.2ms
# Speed: 1.0ms preprocess, 51.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Rock, 51.6ms
# Speed: 1.0ms preprocess, 51.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 52.1ms
# Speed: 1.0ms preprocess, 52.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 50.9ms
# Speed: 0.9ms preprocess, 50.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Papers, 51.6ms
# Speed: 1.0ms preprocess, 51.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 52.3ms
# Speed: 1.0ms preprocess, 52.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Rock, 52.2ms
# Speed: 1.0ms preprocess, 52.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Rock, 54.0ms
# Speed: 1.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Rock, 52.9ms
# Speed: 2.0ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Rock, 51.2ms
# Speed: 2.0ms preprocess, 51.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 51.0ms
# Speed: 1.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Rock, 51.6ms
# Speed: 2.0ms preprocess, 51.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 49.2ms
# Speed: 2.0ms preprocess, 49.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.1ms
# Speed: 2.0ms preprocess, 51.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.7ms
# Speed: 1.0ms preprocess, 52.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 50.8ms
# Speed: 1.0ms preprocess, 50.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 52.0ms
# Speed: 1.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 52.7ms
# Speed: 1.0ms preprocess, 52.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 49.4ms
# Speed: 0.9ms preprocess, 49.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.9ms
# Speed: 1.0ms preprocess, 49.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.8ms
# Speed: 2.0ms preprocess, 48.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 50.4ms
# Speed: 2.0ms preprocess, 50.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 50.8ms
# Speed: 1.0ms preprocess, 50.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.8ms
# Speed: 1.0ms preprocess, 57.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.0ms
# Speed: 1.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 51.9ms
# Speed: 1.0ms preprocess, 51.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.4ms
# Speed: 1.0ms preprocess, 50.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.2ms
# Speed: 1.0ms preprocess, 52.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.0ms
# Speed: 1.0ms preprocess, 57.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 54.9ms
# Speed: 1.0ms preprocess, 54.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 56.0ms
# Speed: 1.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 54.0ms
# Speed: 1.0ms preprocess, 54.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Scissors, 53.2ms
# Speed: 2.0ms preprocess, 53.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 51.9ms
# Speed: 1.0ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 50.8ms
# Speed: 0.9ms preprocess, 50.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 51.3ms
# Speed: 1.0ms preprocess, 51.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 51.1ms
# Speed: 2.0ms preprocess, 51.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 52.3ms
# Speed: 1.0ms preprocess, 52.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 58.5ms
# Speed: 1.2ms preprocess, 58.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Scissors, 52.1ms
# Speed: 1.0ms preprocess, 52.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Scissorss, 52.6ms
# Speed: 1.0ms preprocess, 52.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Scissorss, 56.0ms
# Speed: 0.9ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Papers, 2 Scissorss, 51.3ms
# Speed: 1.0ms preprocess, 51.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Papers, 1 Scissors, 52.5ms
# Speed: 1.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Papers, 54.2ms
# Speed: 1.0ms preprocess, 54.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Papers, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Scissors, 51.9ms
# Speed: 1.0ms preprocess, 51.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Scissors, 52.9ms
# Speed: 1.0ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Scissors, 52.1ms
# Speed: 1.0ms preprocess, 52.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Scissors, 52.0ms
# Speed: 1.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Scissorss, 51.3ms
# Speed: 1.0ms preprocess, 51.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 3 Scissorss, 53.6ms
# Speed: 1.0ms preprocess, 53.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Scissorss, 51.0ms
# Speed: 1.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Scissors, 51.1ms
# Speed: 1.0ms preprocess, 51.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Scissorss, 60.6ms
# Speed: 1.0ms preprocess, 60.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Scissorss, 60.9ms
# Speed: 0.2ms preprocess, 60.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Scissorss, 65.6ms
# Speed: 1.0ms preprocess, 65.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 3 Scissorss, 72.8ms
# Speed: 1.0ms preprocess, 72.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Scissorss, 67.7ms
# Speed: 1.0ms preprocess, 67.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Rock, 2 Scissorss, 71.4ms
# Speed: 2.0ms preprocess, 71.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 2 Rocks, 2 Scissorss, 65.8ms
# Speed: 1.0ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Paper, 1 Rock, 2 Scissorss, 77.8ms
# Speed: 1.0ms preprocess, 77.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Papers, 2 Scissorss, 74.4ms
# Speed: 1.0ms preprocess, 74.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Papers, 1 Rock, 2 Scissorss, 71.3ms
# Speed: 1.0ms preprocess, 71.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Papers, 1 Rock, 1 Scissors, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Papers, 1 Rock, 2 Scissorss, 61.3ms
# Speed: 1.0ms preprocess, 61.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
